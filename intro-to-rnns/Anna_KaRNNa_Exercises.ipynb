# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, we'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()
vocab = sorted(set(text))
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([ 5,  8, 57, 79, 73, 39,  0,  9, 67, 32, 32, 32, 35, 57, 79, 79, 82,
#         9, 45, 57, 68, 10, 50, 10, 39, 60,  9, 57,  0, 39,  9, 57, 50, 50,
#         9, 57, 50, 10, 15, 39, 56,  9, 39, 14, 39,  0, 82,  9, 11, 66,  8,
#        57, 79, 79, 82,  9, 45, 57, 68, 10, 50, 82,  9, 10, 60,  9, 11, 66,
#         8, 57, 79, 79, 82,  9, 10, 66,  9, 10, 73, 60,  9, 36, 48, 66, 32,
#        48, 57, 82, 46, 32, 32, 53, 14, 39,  0, 82, 73,  8, 10, 66])

# %% [markdown]
# Since the network is working with individual characters, it's similar to a classification problem in which we are trying to predict the next character from the previous text.  Here's how many 'classes' our network has to pick from.

# %%
len(vocab)
# Out:
# 83

# %% [markdown]
# ## Making training mini-batches
#
# Here is where we'll make our mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
# We have our text encoded as integers as one long array in `encoded`. Let's create a function that will give us an iterator for our batches. I like using [generator functions](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/) to do this. Then we can pass `encoded` into this function and get our batch generator.
#
# The first thing we need to do is discard some of the text so we only have completely full batches. Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the number of batches we can make from some array `arr`, you divide the length of `arr` by the batch size. Once you know the number of batches and the batch size, you can get the total number of characters to keep.
#
# After that, we need to split `arr` into $N$ sequences. You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences (`n_seqs` below), let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$ where $K$ is the number of batches.
#
# Now that we have this array, we can iterate through it to get our batches. The idea is each batch is a $N \times M$ window on the array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character. You'll usually see the first input character used as the last target character, so something like this:
# ```python
# y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
# ```
# where `x` is the input batch and `y` is the target batch.
#
# The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.
#
# > **Exercise:** Write the code for creating batches in the function below. The exercises in this notebook _will not be easy_. I've provided a notebook with solutions alongside this notebook. If you get stuck, checkout the solutions. The most important thing is that you don't copy and paste the code into here, **type out the solution code yourself.**

# %%
def get_batches(arr, n_seqs, n_steps):
    '''Create a generator that returns batches of size
       n_seqs x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       n_seqs: Batch size, the number of sequences per batch (num of seqs is different from num of batches)
       n_steps: Number of sequence steps per batch
    '''
    # Get the number of characters per batch and number of batches we can make
    characters_per_batch =  n_seqs * n_steps
    n_batches = len(arr) // characters_per_batch
    
    # Keep only enough characters to make full batches
    arr = arr[: n_batches * characters_per_batch]
    
    # Reshape into n_seqs rows
    arr = arr.reshape((n_seqs, n_steps * n_batches))  # arr = arr.reshape((n_seqs, -1))
    
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:, n: n + n_steps]
        # The targets, shifted by one
        y = np.zeros_like(x)
        y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
        yield x, y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
x1, y1 = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
result0 = [int_to_vocab[ele] for ele in x[0, :]]
print(result0)
result1 = [int_to_vocab[ele] for ele in x[1, :]]
print(result1)
result0 = [int_to_vocab[ele] for ele in x1[0, :]]
print(result0)
result1 = [int_to_vocab[ele] for ele in x1[1, :]]
print(result1)
# Out:
# x
#  [[ 5  8 57 79 73 39  0  9 67 32]
#  [ 9 57 68  9 66 36 73  9 75 36]
#  [14 10 66 46 32 32 76 51 39 60]
#  [66  9 62 11  0 10 66 75  9  8]
#  [ 9 10 73  9 10 60 43  9 60 10]
#  [ 9 40 73  9 48 57 60 32 36 66]
#  [ 8 39 66  9 54 36 68 39  9 45]
#  [56  9  7 11 73  9 66 36 48  9]
#  [73  9 10 60 66 74 73 46  9 52]
#  [ 9 60 57 10 62  9 73 36  9  8]]
#
# y
#  [[ 8 57 79 73 39  0  9 67 32 32]
#  [57 68  9 66 36 73  9 75 36 10]
#  [10 66 46 32 32 76 51 39 60 43]
#  [ 9 62 11  0 10 66 75  9  8 10]
#  [10 73  9 10 60 43  9 60 10  0]
#  [40 73  9 48 57 60 32 36 66 50]
#  [39 66  9 54 36 68 39  9 45 36]
#  [ 9  7 11 73  9 66 36 48  9 60]
#  [ 9 10 60 66 74 73 46  9 52  8]
#  [60 57 10 62  9 73 36  9  8 39]]
# ['C', 'h', 'a', 'p', 't', 'e', 'r', ' ', '1', '\n', '\n', '\n', 'H', 'a', 'p', 'p', 'y', ' ', 'f', 'a', 'm', 'i', 'l', 'i', 'e', 's', ' ', 'a', 'r', 'e', ' ', 'a', 'l', 'l', ' ', 'a', 'l', 'i', 'k', 'e', ';', ' ', 'e', 'v', 'e', 'r', 'y', ' ', 'u', 'n']
# [' ', 'a', 'm', ' ', 'n', 'o', 't', ' ', 'g', 'o', 'i', 'n', 'g', ' ', 't', 'o', ' ', 's', 't', 'a', 'y', ',', '"', ' ', 'a', 'n', 's', 'w', 'e', 'r', 'e', 'd', ' ', 'A', 'n', 'n', 'a', ',', ' ', 's', 'm', 'i', 'l', 'i', 'n', 'g', ',', ' ', 'b', 'u']
# ['h', 'a', 'p', 'p', 'y', ' ', 'f', 'a', 'm', 'i', 'l', 'y', ' ', 'i', 's', ' ', 'u', 'n', 'h', 'a', 'p', 'p', 'y', ' ', 'i', 'n', ' ', 'i', 't', 's', ' ', 'o', 'w', 'n', '\n', 'w', 'a', 'y', '.', '\n', '\n', 'E', 'v', 'e', 'r', 'y', 't', 'h', 'i', 'n']
# ['t', ' ', 'i', 'n', ' ', 's', 'p', 'i', 't', 'e', ' ', 'o', 'f', '\n', 'h', 'e', 'r', ' ', 's', 'm', 'i', 'l', 'e', ',', ' ', 'b', 'o', 't', 'h', ' ', 'K', 'o', 'r', 's', 'u', 'n', 's', 'k', 'y', ' ', 'a', 'n', 'd', ' ', 't', 'h', 'e', ' ', 'm', 'a']

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ## Building the model
#
# Below is where you'll build the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
#
# ### Inputs
#
# First off we'll create our input placeholders. As usual we need placeholders for the training data and the targets. We'll also create a placeholder for dropout layers called `keep_prob`. This will be a scalar, that is a 0-D tensor. To make a scalar, you create a placeholder without giving it a size.
#
# > **Exercise:** Create the input placeholders in the function below.

# %%
def build_inputs(batch_size, num_steps):
    ''' Define placeholders for inputs, targets, and dropout 
    
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
        
    '''
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(dtype=tf.int32, shape=(batch_size, num_steps), name="input")
    targets = tf.placeholder(dtype=tf.int32, shape=(batch_size, num_steps), name="targets")
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(dtype=tf.float32, name="input")
    
    return inputs, targets, keep_prob

# %% [markdown]
# ### LSTM Cell
#
# Here we will create the LSTM cell we'll use in the hidden layer. We'll use this cell as a building block for the RNN. So we aren't actually defining the RNN here, just the type of cell we'll use in the hidden layer.
#
# We first create a basic LSTM cell with
#
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
# ```
#
# where `num_units` is the number of units in the hidden layers in the cell. Then we can add dropout by wrapping it with
#
# ```python
# tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
# ```
# You pass in a cell and it will automatically add dropout to the inputs or outputs. Finally, we can stack up the LSTM cells into layers with [`tf.contrib.rnn.MultiRNNCell`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/MultiRNNCell). With this, you pass in a list of cells and it will send the output of one cell into the next cell. Previously with TensorFlow 1.0, you could do this
#
# ```python
# tf.contrib.rnn.MultiRNNCell([cell]*num_layers)
# ```
#
# This might look a little weird if you know Python well because this will create a list of the same `cell` object. However, TensorFlow 1.0 will create different weight matrices for all `cell` objects. But, starting with TensorFlow 1.1 you actually need to create new cell objects in the list. To get it to work in TensorFlow 1.1, it should look like
#
# ```python
# def build_cell(num_units, keep_prob):
#     lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
#     drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
#
#     return drop
#
# tf.contrib.rnn.MultiRNNCell([build_cell(num_units, keep_prob) for _ in range(num_layers)])
# ```
#
# Even though this is actually multiple LSTM cells stacked on each other, you can treat the multiple layers as one cell.
#
# We also need to create an initial cell state of all zeros. This can be done like so
#
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Below, we implement the `build_lstm` function to create these LSTM cells and the initial state.

# %%
def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    def build_cell(num_units, keep_prob):
        lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
        drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)

        return drop

    cell = tf.contrib.rnn.MultiRNNCell([build_cell(lstm_size, keep_prob) for _ in range(num_layers)])
    initial_state = cell.zero_state(batch_size, tf.float32)
    
    
    return cell, initial_state

# %% [markdown]
# ### RNN Output
#
# Here we'll create the output layer. We need to connect the output of the RNN cells to a full connected layer with a softmax output. The softmax output gives us a probability distribution we can use to predict the next character, so we want this layer to have size $C$, the number of classes/characters we have in our text.
#
# If our input has batch size $N$, number of steps $M$, and the hidden layer has $L$ hidden units, then the output is a 3D tensor with size $N \times M \times L$. The output of each LSTM cell has size $L$, we have $M$ of them, one for each sequence step, and we have $N$ sequences. So the total size is $N \times M \times L$.
#
# We are using the same fully connected layer, the same weights, for each of the outputs. Then, to make things easier, we should reshape the outputs into a 2D tensor with shape $(M * N) \times L$. That is, one row for each sequence and step, where the values of each row are the output from the LSTM cells. We get the LSTM output as a list, `lstm_output`. First we need to concatenate this whole list into one array with [`tf.concat`](https://www.tensorflow.org/api_docs/python/tf/concat). Then, reshape it (with `tf.reshape`) to size $(M * N) \times L$.
#
# One we have the outputs reshaped, we can do the matrix multiplication with the weights. We need to wrap the weight and bias variables in a variable scope with `tf.variable_scope(scope_name)` because there are weights being created in the LSTM cells. TensorFlow will throw an error if the weights created here have the same names as the weights created in the LSTM cells, which they will be default. To avoid this, we wrap the variables in a variable scope so we can give them unique names.
#
# > **Exercise:** Implement the output layer in the function below.

# %%
def build_output(lstm_output, in_size, out_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        lstm_output: List of output tensors from the LSTM layer
        in_size: Size of the input tensor, for example, size of the LSTM cells (which might means L in the above instruction?) 
        out_size: Size of this softmax layer. The softmax output gives us a probability distribution we can use to predict the next character,
        so we want this layer to have size C, the number of classes/characters we have in our text.
    
    '''

    # Reshape output so it's a bunch of rows, one row for each step for each sequence.
    # Concatenate lstm_output over axis 1 (the columns)
    # lstm_output is N×M×L and after concatenation the result should be (M∗N)×L 
    seq_output = tf.concat(lstm_output, axis=1)
    print("seq_output.shape: ", seq_output.shape)
    # Reshape seq_output to a 2D tensor with lstm_size columns
    x = tf.reshape(seq_output, shape=(-1, in_size))
    print("x.shape: ", x.shape)
    print("out_size: ", out_size)
    
    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('softmax'):
        # Create the weight and bias variables here
        softmax_w = tf.Variable(tf.truncated_normal(shape=(in_size, out_size), stddev=0.1))
        softmax_b = tf.Variable(tf.zeros(shape=(out_size)))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will be a bunch
    # of rows of logit outputs, one for each step and sequence
    logits = tf.matmul(x, softmax_w) + softmax_b
    
    # Use softmax to get the probabilities for predicted characters
    out = tf.nn.softmax(logits, name='predictions')
    
    return out, logits

# %% [markdown]
# ### Training loss
#
# Next up is the training loss. We get the logits and targets and calculate the softmax cross-entropy loss. First we need to one-hot encode the targets, we're getting them as encoded characters. Then, reshape the one-hot targets so it's a 2D tensor with size $(M*N) \times C$ where $C$ is the number of classes/characters we have. Remember that we reshaped the LSTM outputs and ran them through a fully connected layer with $C$ units. So our logits will also have size $(M*N) \times C$.
#
# Then we run the logits and targets through `tf.nn.softmax_cross_entropy_with_logits` and find the mean to get the loss.
#
# >**Exercise:** Implement the loss calculation in the function below.

# %%
def build_loss(logits, targets, lstm_size, num_classes):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
        logits: Logits from final fully connected layer, shape is (10000, 83)
        targets: Targets for supervised learning, shape is (100, 100)
        lstm_size: Number of LSTM hidden units, 512
        num_classes: Number of classes in targets, 83
        
    '''
    
    # One-hot encode targets and reshape to match logits, one row per sequence per step
    y_one_hot = tf.one_hot(indices=targets, depth=num_classes)
    y_reshaped = tf.reshape(y_one_hot, shape=logits.shape) 
    
    # Softmax cross entropy loss
    loss = tf.nn.softmax_cross_entropy_with_logits(labels=y_reshaped, logits=logits)
    loss = tf.reduce_mean(loss)
    return loss

# %% [markdown]
# ### Optimizer
#
# Here we build the optimizer. Normal RNNs have have issues gradients exploding and disappearing. LSTMs fix the disappearance problem, but the gradients can still grow without bound. To fix this, we can clip the gradients above some threshold. That is, if a gradient is larger than that threshold, we set it to the threshold. This will ensure the gradients never grow overly large. Then we use an AdamOptimizer for the learning step.

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''
    
    # Optimizer for training, using gradient clipping to control exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    return optimizer

# %% [markdown]
# ### Build the network
#
# Now we can put all the pieces together and build a class for the network. To actually run data through the LSTM cells, we will use [`tf.nn.dynamic_rnn`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/nn/dynamic_rnn). This function will pass the hidden and cell states across LSTM cells appropriately for us. It returns the outputs for each LSTM cell at each step for each sequence in the mini-batch. It also gives us the final LSTM state. We want to save this state as `final_state` so we can pass it to the first LSTM cell in the the next mini-batch run. For `tf.nn.dynamic_rnn`, we pass in the cell and initial state we get from `build_lstm`, as well as our input sequences. Also, we need to one-hot encode the inputs before going into the RNN.
#
# > **Exercise:** Use the functions you've implemented previously and `tf.nn.dynamic_rnn` to build the network.

# %%
class CharRNN:
    
    def __init__(self, num_classes, batch_size=64, num_steps=50, 
                       lstm_size=128, num_layers=2, learning_rate=0.001, 
                       grad_clip=5, sampling=False):
    
        # When we're using this network for sampling later, we'll be passing in
        # one character at a time, so providing an option for that
        if sampling == True:
            batch_size, num_steps = 1, 1
        else:
            batch_size, num_steps = batch_size, num_steps

        tf.reset_default_graph()
        
        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(batch_size, num_steps)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers, batch_size, keep_prob)

        ### Run the data through the RNN layers
        # First, one-hot encode the input tokens
        x_one_hot = tf.one_hot(indices=self.inputs, depth=num_classes)
        
        # Run each sequence step through the RNN with tf.nn.dynamic_rnn 
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=self.initial_state)
        self.final_state = state
        
        # Get softmax predictions and logits
        self.prediction, self.logits = build_output(outputs, lstm_size, num_classes) # for the record, lstm_size is the number of hidden layer
        
        # Loss and optimizer (with gradient clipping)
        self.loss = build_loss(self.logits, self.targets, lstm_size, num_classes)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## Hyperparameters
#
# Here are the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 10         # Sequences per batch
num_steps = 50          # Number of sequence steps per batch
lstm_size = 128         # Size of hidden layers in LSTMs
num_layers = 2          # Number of LSTM layers
learning_rate = 0.01    # Learning rate
keep_prob = 0.5         # Dropout keep probability

# %% [markdown]
# ## Time for training
#
# This is typical training code, passing inputs and targets into the network, then running the optimizer. Here we also get back the final LSTM state for the mini-batch. Then, we pass that state back into the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}.ckpt`
#
# > **Exercise:** Set the hyperparameters above to train the network. Watch the training loss, it should be consistently dropping. Also, I highly advise running this on a GPU.

# %%
epochs = 20
# Save every N iterations
save_every_n = 200

model = CharRNN(len(vocab), batch_size=batch_size, num_steps=num_steps,
                lstm_size=lstm_size, num_layers=num_layers, 
                learning_rate=learning_rate)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    for e in range(epochs):
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for x, y in get_batches(encoded, batch_size, num_steps):
            counter += 1
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.loss, 
                                                 model.final_state, 
                                                 model.optimizer], 
                                                 feed_dict=feed)
            
            end = time.time()
            print('Epoch: {}/{}... '.format(e+1, epochs),
                  'Training Step: {}... '.format(counter),
                  'Training loss: {:.4f}... '.format(batch_loss),
                  '{:.4f} sec/batch'.format((end - start)))
        
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
    
    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# seq_output.shape:  (10, 50, 128)
# x.shape:  (500, 128)
# out_size:  83
# Epoch: 1/20...  Training Step: 1...  Training loss: 4.4188...  0.1218 sec/batch
# Epoch: 1/20...  Training Step: 2...  Training loss: 4.3222...  0.0907 sec/batch
# Epoch: 1/20...  Training Step: 3...  Training loss: 3.5222...  0.0927 sec/batch
# Epoch: 1/20...  Training Step: 4...  Training loss: 3.4549...  0.1138 sec/batch
# Epoch: 1/20...  Training Step: 5...  Training loss: 3.2214...  0.0912 sec/batch
# Epoch: 1/20...  Training Step: 6...  Training loss: 3.4040...  0.0953 sec/batch
# Epoch: 1/20...  Training Step: 7...  Training loss: 3.1949...  0.1063 sec/batch
# Epoch: 1/20...  Training Step: 8...  Training loss: 3.2070...  0.0917 sec/batch
# Epoch: 1/20...  Training Step: 9...  Training loss: 3.2565...  0.0877 sec/batch
# Epoch: 1/20...  Training Step: 10...  Training loss: 3.2511...  0.1208 sec/batch
# Epoch: 1/20...  Training Step: 11...  Training loss: 3.2689...  0.1138 sec/batch
# Epoch: 1/20...  Training Step: 12...  Training loss: 3.1827...  0.1063 sec/batch
# Epoch: 1/20...  Training Step: 13...  Training loss: 3.1165...  0.1108 sec/batch
# Epoch: 1/20...  Training Step: 14...  Training loss: 3.1756...  0.1113 sec/batch
# Epoch: 1/20...  Training Step: 15...  Training loss: 3.0884...  0.1033 sec/batch
# Epoch: 1/20...  Training Step: 16...  Training loss: 3.1429...  0.1168 sec/batch
# Epoch: 1/20...  Training Step: 17...  Training loss: 3.1401...  0.1058 sec/batch
# Epoch: 1/20...  Training Step: 18...  Training loss: 3.2582...  0.0973 sec/batch
# Epoch: 1/20...  Training Step: 19...  Training loss: 3.2392...  0.1193 sec/batch
# Epoch: 1/20...  Training Step: 20...  Training loss: 3.1543...  0.1218 sec/batch
# Epoch: 1/20...  Training Step: 21...  Training loss: 3.2237...  0.1163 sec/batch
# Epoch: 1/20...  Training Step: 22...  Training loss: 3.1923...  0.1203 sec/batch
# Epoch: 1/20...  Training Step: 23...  Training loss: 3.1834...  0.1008 sec/batch
# Epoch: 1/20...  Training Step: 24...  Training loss: 3.1646...  0.0958 sec/batch
# Epoch: 1/20...  Training Step: 25...  Training loss: 3.1415...  0.1288 sec/batch
# Epoch: 1/20...  Training Step: 26...  Training loss: 3.1163...  0.1118 sec/batch
# Epoch: 1/20...  Training Step: 27...  Training loss: 3.0390...  0.1258 sec/batch
# Epoch: 1/20...  Training Step: 28...  Training loss: 3.1805...  0.1098 sec/batch
# Epoch: 1/20...  Training Step: 29...  Training loss: 3.1424...  0.1329 sec/batch
# Epoch: 1/20...  Training Step: 30...  Training loss: 3.1588...  0.1053 sec/batch
# Epoch: 1/20...  Training Step: 31...  Training loss: 3.1336...  0.1033 sec/batch
# Epoch: 1/20...  Training Step: 32...  Training loss: 3.1932...  0.1258 sec/batch
# Epoch: 1/20...  Training Step: 33...  Training loss: 3.1693...  0.1003 sec/batch
# Epoch: 1/20...  Training Step: 34...  Training loss: 3.1909...  0.0912 sec/batch
# Epoch: 1/20...  Training Step: 35...  Training loss: 3.1114...  0.1028 sec/batch
# Epoch: 1/20...  Training Step: 36...  Training loss: 3.2150...  0.1038 sec/batch
# Epoch: 1/20...  Training Step: 37...  Training loss: 3.2111...  0.0953 sec/batch
# Epoch: 1/20...  Training Step: 38...  Training loss: 3.1734...  0.0943 sec/batch
# Epoch: 1/20...  Training Step: 39...  Training loss: 3.0791...  0.1203 sec/batch
# Epoch: 1/20...  Training Step: 40...  Training loss: 3.1010...  0.1063 sec/batch
# Epoch: 1/20...  Training Step: 41...  Training loss: 3.0962...  0.1168 sec/batch
# Epoch: 1/20...  Training Step: 42...  Training loss: 3.2276...  0.1118 sec/batch
# Epoch: 1/20...  Training Step: 43...  Training loss: 3.0980...  0.1123 sec/batch
# Epoch: 1/20...  Training Step: 44...  Training loss: 3.1789...  0.1048 sec/batch
# Epoch: 1/20...  Training Step: 45...  Training loss: 3.0830...  0.1233 sec/batch
# Epoch: 1/20...  Training Step: 46...  Training loss: 3.1614...  0.1213 sec/batch
# Epoch: 1/20...  Training Step: 47...  Training loss: 3.1289...  0.1118 sec/batch
# Epoch: 1/20...  Training Step: 48...  Training loss: 3.0703...  0.1053 sec/batch
# Epoch: 1/20...  Training Step: 49...  Training loss: 3.1101...  0.0922 sec/batch
# Epoch: 1/20...  Training Step: 50...  Training loss: 3.1524...  0.1223 sec/batch
# Epoch: 1/20...  Training Step: 51...  Training loss: 3.0712...  0.1349 sec/batch
# Epoch: 1/20...  Training Step: 52...  Training loss: 3.0771...  0.1404 sec/batch
# Epoch: 1/20...  Training Step: 53...  Training loss: 3.1177...  0.1389 sec/batch
# Epoch: 1/20...  Training Step: 54...  Training loss: 3.0826...  0.1098 sec/batch
# Epoch: 1/20...  Training Step: 55...  Training loss: 3.0405...  0.1128 sec/batch
# Epoch: 1/20...  Training Step: 56...  Training loss: 3.0579...  0.1524 sec/batch
# Epoch: 1/20...  Training Step: 57...  Training loss: 3.0596...  0.1509 sec/batch
# Epoch: 1/20...  Training Step: 58...  Training loss: 3.0426...  0.1268 sec/batch
# Epoch: 1/20...  Training Step: 59...  Training loss: 3.0090...  0.1038 sec/batch
# Epoch: 1/20...  Training Step: 60...  Training loss: 2.9988...  0.1208 sec/batch
# Epoch: 1/20...  Training Step: 61...  Training loss: 3.0714...  0.1083 sec/batch
# Epoch: 1/20...  Training Step: 62...  Training loss: 3.0195...  0.1609 sec/batch
# Epoch: 1/20...  Training Step: 63...  Training loss: 2.9805...  0.1173 sec/batch
# Epoch: 1/20...  Training Step: 64...  Training loss: 3.0018...  0.1073 sec/batch
# Epoch: 1/20...  Training Step: 65...  Training loss: 2.9585...  0.1153 sec/batch
# Epoch: 1/20...  Training Step: 66...  Training loss: 3.0026...  0.1288 sec/batch
# Epoch: 1/20...  Training Step: 67...  Training loss: 2.9584...  0.1268 sec/batch
# Epoch: 1/20...  Training Step: 68...  Training loss: 3.0282...  0.1143 sec/batch
# Epoch: 1/20...  Training Step: 69...  Training loss: 3.0405...  0.1208 sec/batch
# Epoch: 1/20...  Training Step: 70...  Training loss: 2.8610...  0.1113 sec/batch
# Epoch: 1/20...  Training Step: 71...  Training loss: 2.9330...  0.1213 sec/batch
# Epoch: 1/20...  Training Step: 72...  Training loss: 2.9562...  0.1083 sec/batch
# Epoch: 1/20...  Training Step: 73...  Training loss: 2.8611...  0.1188 sec/batch
# Epoch: 1/20...  Training Step: 74...  Training loss: 2.9641...  0.1409 sec/batch
# Epoch: 1/20...  Training Step: 75...  Training loss: 2.9266...  0.1489 sec/batch
# Epoch: 1/20...  Training Step: 76...  Training loss: 2.9881...  0.1549 sec/batch
# Epoch: 1/20...  Training Step: 77...  Training loss: 2.8768...  0.1569 sec/batch
# Epoch: 1/20...  Training Step: 78...  Training loss: 2.9459...  0.1384 sec/batch
# Epoch: 1/20...  Training Step: 79...  Training loss: 2.9330...  0.1459 sec/batch
# Epoch: 1/20...  Training Step: 80...  Training loss: 2.7855...  0.1334 sec/batch
# Epoch: 1/20...  Training Step: 81...  Training loss: 3.0057...  0.1554 sec/batch
# Epoch: 1/20...  Training Step: 82...  Training loss: 2.9107...  0.1419 sec/batch
# Epoch: 1/20...  Training Step: 83...  Training loss: 2.9066...  0.1223 sec/batch
# Epoch: 1/20...  Training Step: 84...  Training loss: 2.7837...  0.1283 sec/batch
# Epoch: 1/20...  Training Step: 85...  Training loss: 2.8858...  0.1484 sec/batch
# Epoch: 1/20...  Training Step: 86...  Training loss: 2.7963...  0.1529 sec/batch
# Epoch: 1/20...  Training Step: 87...  Training loss: 2.8016...  0.1128 sec/batch
# Epoch: 1/20...  Training Step: 88...  Training loss: 2.7201...  0.1278 sec/batch
# Epoch: 1/20...  Training Step: 89...  Training loss: 2.7327...  0.1143 sec/batch
# Epoch: 1/20...  Training Step: 90...  Training loss: 2.8420...  0.1484 sec/batch
# Epoch: 1/20...  Training Step: 91...  Training loss: 2.7972...  0.1223 sec/batch
# Epoch: 1/20...  Training Step: 92...  Training loss: 2.8777...  0.1669 sec/batch
# Epoch: 1/20...  Training Step: 93...  Training loss: 2.7991...  0.1469 sec/batch
# Epoch: 1/20...  Training Step: 94...  Training loss: 2.9711...  0.1218 sec/batch
# Epoch: 1/20...  Training Step: 95...  Training loss: 2.8698...  0.1324 sec/batch
# Epoch: 1/20...  Training Step: 96...  Training loss: 2.6891...  0.1298 sec/batch
# Epoch: 1/20...  Training Step: 97...  Training loss: 2.8499...  0.1519 sec/batch
# Epoch: 1/20...  Training Step: 98...  Training loss: 2.7644...  0.1504 sec/batch
# Epoch: 1/20...  Training Step: 99...  Training loss: 2.7480...  0.1068 sec/batch
# Epoch: 1/20...  Training Step: 100...  Training loss: 2.7536...  0.1243 sec/batch
# Epoch: 1/20...  Training Step: 101...  Training loss: 2.8917...  0.1063 sec/batch
# Epoch: 1/20...  Training Step: 102...  Training loss: 2.6884...  0.1198 sec/batch
# Epoch: 1/20...  Training Step: 103...  Training loss: 2.8345...  0.1273 sec/batch
# Epoch: 1/20...  Training Step: 104...  Training loss: 2.5790...  0.1208 sec/batch
# Epoch: 1/20...  Training Step: 105...  Training loss: 2.7975...  0.1233 sec/batch
# Epoch: 1/20...  Training Step: 106...  Training loss: 2.9118...  0.1183 sec/batch
# Epoch: 1/20...  Training Step: 107...  Training loss: 2.7422...  0.1133 sec/batch
# Epoch: 1/20...  Training Step: 108...  Training loss: 2.7016...  0.1173 sec/batch
# Epoch: 1/20...  Training Step: 109...  Training loss: 2.6936...  0.1133 sec/batch
# Epoch: 1/20...  Training Step: 110...  Training loss: 2.8214...  0.1263 sec/batch
# Epoch: 1/20...  Training Step: 111...  Training loss: 2.6412...  0.1043 sec/batch
# Epoch: 1/20...  Training Step: 112...  Training loss: 2.7088...  0.1038 sec/batch
# Epoch: 1/20...  Training Step: 113...  Training loss: 2.6584...  0.1093 sec/batch
# Epoch: 1/20...  Training Step: 114...  Training loss: 2.6272...  0.1038 sec/batch
# Epoch: 1/20...  Training Step: 115...  Training loss: 2.7276...  0.1128 sec/batch
# Epoch: 1/20...  Training Step: 116...  Training loss: 2.7731...  0.0983 sec/batch
# Epoch: 1/20...  Training Step: 117...  Training loss: 2.6884...  0.1434 sec/batch
# Epoch: 1/20...  Training Step: 118...  Training loss: 2.5255...  0.1288 sec/batch
# Epoch: 1/20...  Training Step: 119...  Training loss: 2.6751...  0.1133 sec/batch
# Epoch: 1/20...  Training Step: 120...  Training loss: 2.5744...  0.1153 sec/batch
# Epoch: 1/20...  Training Step: 121...  Training loss: 2.5478...  0.1354 sec/batch
# Epoch: 1/20...  Training Step: 122...  Training loss: 2.6178...  0.1248 sec/batch
# Epoch: 1/20...  Training Step: 123...  Training loss: 2.7116...  0.0902 sec/batch
# Epoch: 1/20...  Training Step: 124...  Training loss: 2.6028...  0.1068 sec/batch
# Epoch: 1/20...  Training Step: 125...  Training loss: 2.6666...  0.1218 sec/batch
# Epoch: 1/20...  Training Step: 126...  Training loss: 2.5836...  0.1158 sec/batch
# Epoch: 1/20...  Training Step: 127...  Training loss: 2.5028...  0.1128 sec/batch
# Epoch: 1/20...  Training Step: 128...  Training loss: 2.5373...  0.1088 sec/batch
# Epoch: 1/20...  Training Step: 129...  Training loss: 2.5469...  0.0993 sec/batch
# Epoch: 1/20...  Training Step: 130...  Training loss: 2.4872...  0.1038 sec/batch
# Epoch: 1/20...  Training Step: 131...  Training loss: 2.5127...  0.0978 sec/batch
# Epoch: 1/20...  Training Step: 132...  Training loss: 2.5915...  0.1103 sec/batch
# Epoch: 1/20...  Training Step: 133...  Training loss: 2.5847...  0.0922 sec/batch
# Epoch: 1/20...  Training Step: 134...  Training loss: 2.5863...  0.1053 sec/batch
# Epoch: 1/20...  Training Step: 135...  Training loss: 2.6653...  0.1043 sec/batch
# Epoch: 1/20...  Training Step: 136...  Training loss: 2.4086...  0.1018 sec/batch
# Epoch: 1/20...  Training Step: 137...  Training loss: 2.6244...  0.1093 sec/batch
# Epoch: 1/20...  Training Step: 138...  Training loss: 2.5499...  0.1293 sec/batch
# Epoch: 1/20...  Training Step: 139...  Training loss: 2.5485...  0.1188 sec/batch
# Epoch: 1/20...  Training Step: 140...  Training loss: 2.5996...  0.1313 sec/batch
# Epoch: 1/20...  Training Step: 141...  Training loss: 2.5272...  0.1148 sec/batch
# Epoch: 1/20...  Training Step: 142...  Training loss: 2.5507...  0.1218 sec/batch
# Epoch: 1/20...  Training Step: 143...  Training loss: 2.6501...  0.1243 sec/batch
# Epoch: 1/20...  Training Step: 144...  Training loss: 2.6246...  0.1188 sec/batch
# Epoch: 1/20...  Training Step: 145...  Training loss: 2.4873...  0.1318 sec/batch
# Epoch: 1/20...  Training Step: 146...  Training loss: 2.4847...  0.1293 sec/batch
# Epoch: 1/20...  Training Step: 147...  Training loss: 2.5764...  0.1359 sec/batch
# Epoch: 1/20...  Training Step: 148...  Training loss: 2.4656...  0.1133 sec/batch
# Epoch: 1/20...  Training Step: 149...  Training loss: 2.5007...  0.1033 sec/batch
# Epoch: 1/20...  Training Step: 150...  Training loss: 2.5040...  0.1098 sec/batch
# Epoch: 1/20...  Training Step: 151...  Training loss: 2.5334...  0.1053 sec/batch
# Epoch: 1/20...  Training Step: 152...  Training loss: 2.4598...  0.1203 sec/batch
# Epoch: 1/20...  Training Step: 153...  Training loss: 2.5376...  0.1434 sec/batch
# Epoch: 1/20...  Training Step: 154...  Training loss: 2.5079...  0.1323 sec/batch
# Epoch: 1/20...  Training Step: 155...  Training loss: 2.5985...  0.1379 sec/batch
# Epoch: 1/20...  Training Step: 156...  Training loss: 2.5743...  0.1173 sec/batch
# Epoch: 1/20...  Training Step: 157...  Training loss: 2.3829...  0.1198 sec/batch
# Epoch: 1/20...  Training Step: 158...  Training loss: 2.5239...  0.1163 sec/batch
# Epoch: 1/20...  Training Step: 159...  Training loss: 2.6923...  0.1138 sec/batch
# Epoch: 1/20...  Training Step: 160...  Training loss: 2.5379...  0.1053 sec/batch
# Epoch: 1/20...  Training Step: 161...  Training loss: 2.4437...  0.1133 sec/batch
# Epoch: 1/20...  Training Step: 162...  Training loss: 2.5127...  0.1038 sec/batch
# Epoch: 1/20...  Training Step: 163...  Training loss: 2.4429...  0.0963 sec/batch
# Epoch: 1/20...  Training Step: 164...  Training loss: 2.4081...  0.1113 sec/batch
# Epoch: 1/20...  Training Step: 165...  Training loss: 2.5182...  0.1048 sec/batch
# Epoch: 1/20...  Training Step: 166...  Training loss: 2.4421...  0.0973 sec/batch
# Epoch: 1/20...  Training Step: 167...  Training loss: 2.4603...  0.1048 sec/batch
# Epoch: 1/20...  Training Step: 168...  Training loss: 2.5840...  0.0948 sec/batch
# Epoch: 1/20...  Training Step: 169...  Training loss: 2.6265...  0.1103 sec/batch
# Epoch: 1/20...  Training Step: 170...  Training loss: 2.4685...  0.1133 sec/batch
# Epoch: 1/20...  Training Step: 171...  Training loss: 2.5209...  0.1033 sec/batch
# Epoch: 1/20...  Training Step: 172...  Training loss: 2.4510...  0.1023 sec/batch
# Epoch: 1/20...  Training Step: 173...  Training loss: 2.5445...  0.1183 sec/batch
# Epoch: 1/20...  Training Step: 174...  Training loss: 2.5920...  0.1148 sec/batch
# Epoch: 1/20...  Training Step: 175...  Training loss: 2.5951...  0.1068 sec/batch
# Epoch: 1/20...  Training Step: 176...  Training loss: 2.3783...  0.1574 sec/batch
# Epoch: 1/20...  Training Step: 177...  Training loss: 2.3746...  0.1384 sec/batch
# Epoch: 1/20...  Training Step: 178...  Training loss: 2.4121...  0.1043 sec/batch
# Epoch: 1/20...  Training Step: 179...  Training loss: 2.5997...  0.0948 sec/batch
# Epoch: 1/20...  Training Step: 180...  Training loss: 2.3789...  0.1103 sec/batch
# Epoch: 1/20...  Training Step: 181...  Training loss: 2.2962...  0.1098 sec/batch
# Epoch: 1/20...  Training Step: 182...  Training loss: 2.4805...  0.1063 sec/batch
# Epoch: 1/20...  Training Step: 183...  Training loss: 2.4610...  0.1103 sec/batch
# Epoch: 1/20...  Training Step: 184...  Training loss: 2.4619...  0.1043 sec/batch
# Epoch: 1/20...  Training Step: 185...  Training loss: 2.4605...  0.1093 sec/batch
# Epoch: 1/20...  Training Step: 186...  Training loss: 2.4834...  0.1023 sec/batch
# Epoch: 1/20...  Training Step: 187...  Training loss: 2.3728...  0.1148 sec/batch
# Epoch: 1/20...  Training Step: 188...  Training loss: 2.3989...  0.1248 sec/batch
# Epoch: 1/20...  Training Step: 189...  Training loss: 2.4725...  0.1008 sec/batch
# Epoch: 1/20...  Training Step: 190...  Training loss: 2.4150...  0.1013 sec/batch
# Epoch: 1/20...  Training Step: 191...  Training loss: 2.4407...  0.1298 sec/batch
# Epoch: 1/20...  Training Step: 192...  Training loss: 2.3691...  0.0973 sec/batch
# Epoch: 1/20...  Training Step: 193...  Training loss: 2.4529...  0.1013 sec/batch
# Epoch: 1/20...  Training Step: 194...  Training loss: 2.5922...  0.1083 sec/batch
# Epoch: 1/20...  Training Step: 195...  Training loss: 2.5009...  0.1063 sec/batch
# Epoch: 1/20...  Training Step: 196...  Training loss: 2.5332...  0.1058 sec/batch
# Epoch: 1/20...  Training Step: 197...  Training loss: 2.3112...  0.1068 sec/batch
# Epoch: 1/20...  Training Step: 198...  Training loss: 2.5070...  0.0912 sec/batch
# Epoch: 1/20...  Training Step: 199...  Training loss: 2.5667...  0.1073 sec/batch
# Epoch: 1/20...  Training Step: 200...  Training loss: 2.5401...  0.1369 sec/batch
# Epoch: 1/20...  Training Step: 201...  Training loss: 2.4600...  0.1293 sec/batch
# Epoch: 1/20...  Training Step: 202...  Training loss: 2.4107...  0.1579 sec/batch
# Epoch: 1/20...  Training Step: 203...  Training loss: 2.5055...  0.1389 sec/batch
# Epoch: 1/20...  Training Step: 204...  Training loss: 2.5939...  0.1118 sec/batch
# Epoch: 1/20...  Training Step: 205...  Training loss: 2.4476...  0.1253 sec/batch
# Epoch: 1/20...  Training Step: 206...  Training loss: 2.4828...  0.1494 sec/batch
# Epoch: 1/20...  Training Step: 207...  Training loss: 2.4464...  0.1499 sec/batch
# Epoch: 1/20...  Training Step: 208...  Training loss: 2.4580...  0.1619 sec/batch
# Epoch: 1/20...  Training Step: 209...  Training loss: 2.4360...  0.1319 sec/batch
# Epoch: 1/20...  Training Step: 210...  Training loss: 2.3849...  0.1153 sec/batch
# Epoch: 1/20...  Training Step: 211...  Training loss: 2.3958...  0.1063 sec/batch
# Epoch: 1/20...  Training Step: 212...  Training loss: 2.4060...  0.1394 sec/batch
# Epoch: 1/20...  Training Step: 213...  Training loss: 2.4288...  0.1143 sec/batch
# Epoch: 1/20...  Training Step: 214...  Training loss: 2.4574...  0.1188 sec/batch
# Epoch: 1/20...  Training Step: 215...  Training loss: 2.4007...  0.1529 sec/batch
# Epoch: 1/20...  Training Step: 216...  Training loss: 2.3328...  0.1158 sec/batch
# Epoch: 1/20...  Training Step: 217...  Training loss: 2.4628...  0.1008 sec/batch
# Epoch: 1/20...  Training Step: 218...  Training loss: 2.3390...  0.1113 sec/batch
# Epoch: 1/20...  Training Step: 219...  Training loss: 2.3019...  0.0932 sec/batch
# Epoch: 1/20...  Training Step: 220...  Training loss: 2.4303...  0.1143 sec/batch
# Epoch: 1/20...  Training Step: 221...  Training loss: 2.4532...  0.0887 sec/batch
# Epoch: 1/20...  Training Step: 222...  Training loss: 2.3842...  0.1003 sec/batch
# Epoch: 1/20...  Training Step: 223...  Training loss: 2.4283...  0.1068 sec/batch
# Epoch: 1/20...  Training Step: 224...  Training loss: 2.3643...  0.0897 sec/batch
# Epoch: 1/20...  Training Step: 225...  Training loss: 2.4834...  0.0907 sec/batch
# Epoch: 1/20...  Training Step: 226...  Training loss: 2.4216...  0.1384 sec/batch
# Epoch: 1/20...  Training Step: 227...  Training loss: 2.4705...  0.1213 sec/batch
# Epoch: 1/20...  Training Step: 228...  Training loss: 2.5117...  0.1329 sec/batch
# Epoch: 1/20...  Training Step: 229...  Training loss: 2.3822...  0.1063 sec/batch
# Epoch: 1/20...  Training Step: 230...  Training loss: 2.3543...  0.0917 sec/batch
# Epoch: 1/20...  Training Step: 231...  Training loss: 2.3040...  0.1349 sec/batch
# Epoch: 1/20...  Training Step: 232...  Training loss: 2.3046...  0.1053 sec/batch
# Epoch: 1/20...  Training Step: 233...  Training loss: 2.4174...  0.1183 sec/batch
# Epoch: 1/20...  Training Step: 234...  Training loss: 2.4926...  0.0988 sec/batch
# Epoch: 1/20...  Training Step: 235...  Training loss: 2.5168...  0.1288 sec/batch
# Epoch: 1/20...  Training Step: 236...  Training loss: 2.4794...  0.1319 sec/batch
# Epoch: 1/20...  Training Step: 237...  Training loss: 2.4044...  0.1238 sec/batch
# Epoch: 1/20...  Training Step: 238...  Training loss: 2.5651...  0.1173 sec/batch
# Epoch: 1/20...  Training Step: 239...  Training loss: 2.4269...  0.1424 sec/batch
# Epoch: 1/20...  Training Step: 240...  Training loss: 2.2692...  0.1073 sec/batch
# Epoch: 1/20...  Training Step: 241...  Training loss: 2.4132...  0.0993 sec/batch
# Epoch: 1/20...  Training Step: 242...  Training loss: 2.5190...  0.1233 sec/batch
# Epoch: 1/20...  Training Step: 243...  Training loss: 2.5378...  0.1118 sec/batch
# Epoch: 1/20...  Training Step: 244...  Training loss: 2.5395...  0.0998 sec/batch
# Epoch: 1/20...  Training Step: 245...  Training loss: 2.5029...  0.1058 sec/batch
# Epoch: 1/20...  Training Step: 246...  Training loss: 2.4324...  0.1278 sec/batch
# Epoch: 1/20...  Training Step: 247...  Training loss: 2.2919...  0.1329 sec/batch
# Epoch: 1/20...  Training Step: 248...  Training loss: 2.3862...  0.1394 sec/batch
# Epoch: 1/20...  Training Step: 249...  Training loss: 2.2654...  0.1509 sec/batch
# Epoch: 1/20...  Training Step: 250...  Training loss: 2.4867...  0.1374 sec/batch
# Epoch: 1/20...  Training Step: 251...  Training loss: 2.3910...  0.1223 sec/batch
# Epoch: 1/20...  Training Step: 252...  Training loss: 2.5500...  0.1389 sec/batch
# Epoch: 1/20...  Training Step: 253...  Training loss: 2.3262...  0.1654 sec/batch
# Epoch: 1/20...  Training Step: 254...  Training loss: 2.3710...  0.1384 sec/batch
# Epoch: 1/20...  Training Step: 255...  Training loss: 2.4762...  0.1975 sec/batch
# Epoch: 1/20...  Training Step: 256...  Training loss: 2.3672...  0.1233 sec/batch
# Epoch: 1/20...  Training Step: 257...  Training loss: 2.3842...  0.1053 sec/batch
# Epoch: 1/20...  Training Step: 258...  Training loss: 2.3858...  0.1133 sec/batch
# Epoch: 1/20...  Training Step: 259...  Training loss: 2.3727...  0.1148 sec/batch
# Epoch: 1/20...  Training Step: 260...  Training loss: 2.3291...  0.1168 sec/batch
# Epoch: 1/20...  Training Step: 261...  Training loss: 2.3032...  0.1414 sec/batch
# Epoch: 1/20...  Training Step: 262...  Training loss: 2.3791...  0.1389 sec/batch
# Epoch: 1/20...  Training Step: 263...  Training loss: 2.3887...  0.1283 sec/batch
# Epoch: 1/20...  Training Step: 264...  Training loss: 2.3581...  0.1208 sec/batch
# Epoch: 1/20...  Training Step: 265...  Training loss: 2.2828...  0.1384 sec/batch
# Epoch: 1/20...  Training Step: 266...  Training loss: 2.2949...  0.1283 sec/batch
# Epoch: 1/20...  Training Step: 267...  Training loss: 2.3589...  0.1203 sec/batch
# Epoch: 1/20...  Training Step: 268...  Training loss: 2.2952...  0.1329 sec/batch
# Epoch: 1/20...  Training Step: 269...  Training loss: 2.3823...  0.1424 sec/batch
# Epoch: 1/20...  Training Step: 270...  Training loss: 2.4124...  0.1569 sec/batch
# Epoch: 1/20...  Training Step: 271...  Training loss: 2.4004...  0.1113 sec/batch
# Epoch: 1/20...  Training Step: 272...  Training loss: 2.3637...  0.1208 sec/batch
# Epoch: 1/20...  Training Step: 273...  Training loss: 2.4662...  0.1128 sec/batch
# Epoch: 1/20...  Training Step: 274...  Training loss: 2.3264...  0.1063 sec/batch
# Epoch: 1/20...  Training Step: 275...  Training loss: 2.3579...  0.1098 sec/batch
# Epoch: 1/20...  Training Step: 276...  Training loss: 2.2578...  0.1248 sec/batch
# Epoch: 1/20...  Training Step: 277...  Training loss: 2.4424...  0.1313 sec/batch
# Epoch: 1/20...  Training Step: 278...  Training loss: 2.4324...  0.1394 sec/batch
# Epoch: 1/20...  Training Step: 279...  Training loss: 2.3393...  0.1203 sec/batch
# Epoch: 1/20...  Training Step: 280...  Training loss: 2.3229...  0.1118 sec/batch
# Epoch: 1/20...  Training Step: 281...  Training loss: 2.3715...  0.1133 sec/batch
# Epoch: 1/20...  Training Step: 282...  Training loss: 2.3836...  0.1213 sec/batch
# Epoch: 1/20...  Training Step: 283...  Training loss: 2.2513...  0.1263 sec/batch
# Epoch: 1/20...  Training Step: 284...  Training loss: 2.4900...  0.1123 sec/batch
# Epoch: 1/20...  Training Step: 285...  Training loss: 2.3485...  0.1329 sec/batch
# Epoch: 1/20...  Training Step: 286...  Training loss: 2.2330...  0.1258 sec/batch
# Epoch: 1/20...  Training Step: 287...  Training loss: 2.2526...  0.1439 sec/batch
# Epoch: 1/20...  Training Step: 288...  Training loss: 2.4720...  0.1203 sec/batch
# Epoch: 1/20...  Training Step: 289...  Training loss: 2.2977...  0.1243 sec/batch
# Epoch: 1/20...  Training Step: 290...  Training loss: 2.2791...  0.1238 sec/batch
# Epoch: 1/20...  Training Step: 291...  Training loss: 2.1901...  0.1419 sec/batch
# Epoch: 1/20...  Training Step: 292...  Training loss: 2.2738...  0.1339 sec/batch
# Epoch: 1/20...  Training Step: 293...  Training loss: 2.3308...  0.1218 sec/batch
# Epoch: 1/20...  Training Step: 294...  Training loss: 2.2950...  0.1329 sec/batch
# Epoch: 1/20...  Training Step: 295...  Training loss: 2.4043...  0.1183 sec/batch
# Epoch: 1/20...  Training Step: 296...  Training loss: 2.3654...  0.1133 sec/batch
# Epoch: 1/20...  Training Step: 297...  Training loss: 2.2649...  0.0973 sec/batch
# Epoch: 1/20...  Training Step: 298...  Training loss: 2.2931...  0.1349 sec/batch
# Epoch: 1/20...  Training Step: 299...  Training loss: 2.2810...  0.1419 sec/batch
# Epoch: 1/20...  Training Step: 300...  Training loss: 2.3219...  0.1218 sec/batch
# Epoch: 1/20...  Training Step: 301...  Training loss: 2.2960...  0.1133 sec/batch
# Epoch: 1/20...  Training Step: 302...  Training loss: 2.3129...  0.1148 sec/batch
# Epoch: 1/20...  Training Step: 303...  Training loss: 2.2310...  0.1193 sec/batch
# Epoch: 1/20...  Training Step: 304...  Training loss: 2.3203...  0.1369 sec/batch
# Epoch: 1/20...  Training Step: 305...  Training loss: 2.3697...  0.1253 sec/batch
# Epoch: 1/20...  Training Step: 306...  Training loss: 2.2587...  0.1223 sec/batch
# Epoch: 1/20...  Training Step: 307...  Training loss: 2.3548...  0.1113 sec/batch
# Epoch: 1/20...  Training Step: 308...  Training loss: 2.3004...  0.1128 sec/batch
# Epoch: 1/20...  Training Step: 309...  Training loss: 2.3016...  0.1218 sec/batch
# Epoch: 1/20...  Training Step: 310...  Training loss: 2.3085...  0.1334 sec/batch
# Epoch: 1/20...  Training Step: 311...  Training loss: 2.3764...  0.1399 sec/batch
# Epoch: 1/20...  Training Step: 312...  Training loss: 2.2958...  0.1705 sec/batch
# Epoch: 1/20...  Training Step: 313...  Training loss: 2.2590...  0.1895 sec/batch
# Epoch: 1/20...  Training Step: 314...  Training loss: 2.2421...  0.1985 sec/batch
# Epoch: 1/20...  Training Step: 315...  Training loss: 2.2979...  0.1439 sec/batch
# Epoch: 1/20...  Training Step: 316...  Training loss: 2.3685...  0.1128 sec/batch
# Epoch: 1/20...  Training Step: 317...  Training loss: 2.4173...  0.1454 sec/batch
# Epoch: 1/20...  Training Step: 318...  Training loss: 2.3634...  0.1439 sec/batch
# Epoch: 1/20...  Training Step: 319...  Training loss: 2.3165...  0.1353 sec/batch
# Epoch: 1/20...  Training Step: 320...  Training loss: 2.3314...  0.1399 sec/batch
# Epoch: 1/20...  Training Step: 321...  Training loss: 2.2799...  0.1278 sec/batch
# Epoch: 1/20...  Training Step: 322...  Training loss: 2.2177...  0.0983 sec/batch
# Epoch: 1/20...  Training Step: 323...  Training loss: 2.3281...  0.1088 sec/batch
# Epoch: 1/20...  Training Step: 324...  Training loss: 2.3481...  0.0973 sec/batch
# Epoch: 1/20...  Training Step: 325...  Training loss: 2.2860...  0.1073 sec/batch
# Epoch: 1/20...  Training Step: 326...  Training loss: 2.2565...  0.1028 sec/batch
# Epoch: 1/20...  Training Step: 327...  Training loss: 2.3285...  0.1058 sec/batch
# Epoch: 1/20...  Training Step: 328...  Training loss: 2.2472...  0.1093 sec/batch
# Epoch: 1/20...  Training Step: 329...  Training loss: 2.3940...  0.0968 sec/batch
# Epoch: 1/20...  Training Step: 330...  Training loss: 2.3304...  0.0892 sec/batch
# Epoch: 1/20...  Training Step: 331...  Training loss: 2.2043...  0.1238 sec/batch
# Epoch: 1/20...  Training Step: 332...  Training loss: 2.3702...  0.1183 sec/batch
# Epoch: 1/20...  Training Step: 333...  Training loss: 2.3046...  0.1028 sec/batch
# Epoch: 1/20...  Training Step: 334...  Training loss: 2.2746...  0.1113 sec/batch
# Epoch: 1/20...  Training Step: 335...  Training loss: 2.3418...  0.1293 sec/batch
# Epoch: 1/20...  Training Step: 336...  Training loss: 2.2994...  0.1048 sec/batch
# Epoch: 1/20...  Training Step: 337...  Training loss: 2.3032...  0.0988 sec/batch
# Epoch: 1/20...  Training Step: 338...  Training loss: 2.1404...  0.0978 sec/batch
# Epoch: 1/20...  Training Step: 339...  Training loss: 2.3265...  0.1003 sec/batch
# Epoch: 1/20...  Training Step: 340...  Training loss: 2.2880...  0.1033 sec/batch
# Epoch: 1/20...  Training Step: 341...  Training loss: 2.4381...  0.1113 sec/batch
# Epoch: 1/20...  Training Step: 342...  Training loss: 2.4355...  0.1053 sec/batch
# Epoch: 1/20...  Training Step: 343...  Training loss: 2.4270...  0.0922 sec/batch
# Epoch: 1/20...  Training Step: 344...  Training loss: 2.3260...  0.0988 sec/batch
# Epoch: 1/20...  Training Step: 345...  Training loss: 2.2992...  0.1033 sec/batch
# Epoch: 1/20...  Training Step: 346...  Training loss: 2.3599...  0.1098 sec/batch
# Epoch: 1/20...  Training Step: 347...  Training loss: 2.3854...  0.1048 sec/batch
# Epoch: 1/20...  Training Step: 348...  Training loss: 2.2993...  0.0998 sec/batch
# Epoch: 1/20...  Training Step: 349...  Training loss: 2.2764...  0.1028 sec/batch
# Epoch: 1/20...  Training Step: 350...  Training loss: 2.2226...  0.1108 sec/batch
# Epoch: 1/20...  Training Step: 351...  Training loss: 2.2737...  0.0882 sec/batch
# Epoch: 1/20...  Training Step: 352...  Training loss: 2.2607...  0.0912 sec/batch
# Epoch: 1/20...  Training Step: 353...  Training loss: 2.4145...  0.0983 sec/batch
# Epoch: 1/20...  Training Step: 354...  Training loss: 2.2832...  0.1008 sec/batch
# Epoch: 1/20...  Training Step: 355...  Training loss: 2.3603...  0.1068 sec/batch
# Epoch: 1/20...  Training Step: 356...  Training loss: 2.3542...  0.1108 sec/batch
# Epoch: 1/20...  Training Step: 357...  Training loss: 2.4554...  0.1128 sec/batch
# Epoch: 1/20...  Training Step: 358...  Training loss: 2.3172...  0.0988 sec/batch
# Epoch: 1/20...  Training Step: 359...  Training loss: 2.2270...  0.1068 sec/batch
# Epoch: 1/20...  Training Step: 360...  Training loss: 2.2929...  0.1073 sec/batch
# Epoch: 1/20...  Training Step: 361...  Training loss: 2.3097...  0.1143 sec/batch
# Epoch: 1/20...  Training Step: 362...  Training loss: 2.3949...  0.1153 sec/batch
# Epoch: 1/20...  Training Step: 363...  Training loss: 2.4477...  0.1519 sec/batch
# Epoch: 1/20...  Training Step: 364...  Training loss: 2.2513...  0.0953 sec/batch
# Epoch: 1/20...  Training Step: 365...  Training loss: 2.3133...  0.1043 sec/batch
# Epoch: 1/20...  Training Step: 366...  Training loss: 2.2643...  0.1153 sec/batch
# Epoch: 1/20...  Training Step: 367...  Training loss: 2.3316...  0.1208 sec/batch
# Epoch: 1/20...  Training Step: 368...  Training loss: 2.3557...  0.1223 sec/batch
# Epoch: 1/20...  Training Step: 369...  Training loss: 2.3369...  0.1143 sec/batch
# Epoch: 1/20...  Training Step: 370...  Training loss: 2.2783...  0.1163 sec/batch
# Epoch: 1/20...  Training Step: 371...  Training loss: 2.2854...  0.1068 sec/batch
# Epoch: 1/20...  Training Step: 372...  Training loss: 2.3170...  0.1043 sec/batch
# Epoch: 1/20...  Training Step: 373...  Training loss: 2.2308...  0.1138 sec/batch
# Epoch: 1/20...  Training Step: 374...  Training loss: 2.1269...  0.1108 sec/batch
# Epoch: 1/20...  Training Step: 375...  Training loss: 2.2691...  0.0998 sec/batch
# Epoch: 1/20...  Training Step: 376...  Training loss: 2.3327...  0.1018 sec/batch
# Epoch: 1/20...  Training Step: 377...  Training loss: 2.4113...  0.1038 sec/batch
# Epoch: 1/20...  Training Step: 378...  Training loss: 2.1859...  0.1068 sec/batch
# Epoch: 1/20...  Training Step: 379...  Training loss: 2.2967...  0.1359 sec/batch
# Epoch: 1/20...  Training Step: 380...  Training loss: 2.1742...  0.1203 sec/batch
# Epoch: 1/20...  Training Step: 381...  Training loss: 2.2484...  0.1454 sec/batch
# Epoch: 1/20...  Training Step: 382...  Training loss: 2.2605...  0.1198 sec/batch
# Epoch: 1/20...  Training Step: 383...  Training loss: 2.2710...  0.1093 sec/batch
# Epoch: 1/20...  Training Step: 384...  Training loss: 2.4062...  0.1319 sec/batch
# Epoch: 1/20...  Training Step: 385...  Training loss: 2.3120...  0.1439 sec/batch
# Epoch: 1/20...  Training Step: 386...  Training loss: 2.2111...  0.1439 sec/batch
# Epoch: 1/20...  Training Step: 387...  Training loss: 2.3398...  0.1288 sec/batch
# Epoch: 1/20...  Training Step: 388...  Training loss: 2.3135...  0.1374 sec/batch
# Epoch: 1/20...  Training Step: 389...  Training loss: 2.1545...  0.1178 sec/batch
# Epoch: 1/20...  Training Step: 390...  Training loss: 2.1968...  0.1178 sec/batch
# Epoch: 1/20...  Training Step: 391...  Training loss: 2.1090...  0.1018 sec/batch
# Epoch: 1/20...  Training Step: 392...  Training loss: 2.2694...  0.1118 sec/batch
# Epoch: 1/20...  Training Step: 393...  Training loss: 2.3456...  0.1068 sec/batch
# Epoch: 1/20...  Training Step: 394...  Training loss: 2.2487...  0.0988 sec/batch
# Epoch: 1/20...  Training Step: 395...  Training loss: 2.2563...  0.0927 sec/batch
# Epoch: 1/20...  Training Step: 396...  Training loss: 2.3048...  0.1063 sec/batch
# Epoch: 1/20...  Training Step: 397...  Training loss: 2.2457...  0.1063 sec/batch
# Epoch: 1/20...  Training Step: 398...  Training loss: 2.3333...  0.1334 sec/batch
# Epoch: 1/20...  Training Step: 399...  Training loss: 2.2411...  0.1213 sec/batch
# Epoch: 1/20...  Training Step: 400...  Training loss: 2.2713...  0.1158 sec/batch
# Epoch: 1/20...  Training Step: 401...  Training loss: 2.2244...  0.1118 sec/batch
# Epoch: 1/20...  Training Step: 402...  Training loss: 2.1940...  0.1093 sec/batch
# Epoch: 1/20...  Training Step: 403...  Training loss: 2.2482...  0.1188 sec/batch
# Epoch: 1/20...  Training Step: 404...  Training loss: 2.2154...  0.1339 sec/batch
# Epoch: 1/20...  Training Step: 405...  Training loss: 2.2596...  0.1308 sec/batch
# Epoch: 1/20...  Training Step: 406...  Training loss: 2.2283...  0.1444 sec/batch
# Epoch: 1/20...  Training Step: 407...  Training loss: 2.3067...  0.1108 sec/batch
# Epoch: 1/20...  Training Step: 408...  Training loss: 2.2304...  0.1389 sec/batch
# Epoch: 1/20...  Training Step: 409...  Training loss: 2.2539...  0.1178 sec/batch
# Epoch: 1/20...  Training Step: 410...  Training loss: 2.2396...  0.1253 sec/batch
# Epoch: 1/20...  Training Step: 411...  Training loss: 2.2464...  0.1213 sec/batch
# Epoch: 1/20...  Training Step: 412...  Training loss: 2.2406...  0.1419 sec/batch
# Epoch: 1/20...  Training Step: 413...  Training loss: 2.3763...  0.1188 sec/batch
# Epoch: 1/20...  Training Step: 414...  Training loss: 2.1425...  0.0978 sec/batch
# Epoch: 1/20...  Training Step: 415...  Training loss: 2.1680...  0.1339 sec/batch
# Epoch: 1/20...  Training Step: 416...  Training loss: 2.1702...  0.1344 sec/batch
# Epoch: 1/20...  Training Step: 417...  Training loss: 2.3243...  0.1093 sec/batch
# Epoch: 1/20...  Training Step: 418...  Training loss: 2.1530...  0.1073 sec/batch
# Epoch: 1/20...  Training Step: 419...  Training loss: 2.2034...  0.0998 sec/batch
# Epoch: 1/20...  Training Step: 420...  Training loss: 2.2383...  0.1253 sec/batch
# Epoch: 1/20...  Training Step: 421...  Training loss: 2.2335...  0.1319 sec/batch
# Epoch: 1/20...  Training Step: 422...  Training loss: 2.2360...  0.1364 sec/batch
# Epoch: 1/20...  Training Step: 423...  Training loss: 2.3058...  0.1188 sec/batch
# Epoch: 1/20...  Training Step: 424...  Training loss: 2.1514...  0.1168 sec/batch
# Epoch: 1/20...  Training Step: 425...  Training loss: 2.2720...  0.1569 sec/batch
# Epoch: 1/20...  Training Step: 426...  Training loss: 2.2279...  0.1494 sec/batch
# Epoch: 1/20...  Training Step: 427...  Training loss: 2.2600...  0.1529 sec/batch
# Epoch: 1/20...  Training Step: 428...  Training loss: 2.1772...  0.1845 sec/batch
# Epoch: 1/20...  Training Step: 429...  Training loss: 2.2829...  0.1639 sec/batch
# Epoch: 1/20...  Training Step: 430...  Training loss: 2.2137...  0.1890 sec/batch
# Epoch: 1/20...  Training Step: 431...  Training loss: 2.1520...  0.1659 sec/batch
# Epoch: 1/20...  Training Step: 432...  Training loss: 2.1554...  0.1168 sec/batch
# Epoch: 1/20...  Training Step: 433...  Training loss: 2.1860...  0.1288 sec/batch
# Epoch: 1/20...  Training Step: 434...  Training loss: 2.2008...  0.1715 sec/batch
# Epoch: 1/20...  Training Step: 435...  Training loss: 2.1556...  0.1233 sec/batch
# Epoch: 1/20...  Training Step: 436...  Training loss: 2.1959...  0.1589 sec/batch
# Epoch: 1/20...  Training Step: 437...  Training loss: 2.2028...  0.1900 sec/batch
# Epoch: 1/20...  Training Step: 438...  Training loss: 2.0544...  0.1439 sec/batch
# Epoch: 1/20...  Training Step: 439...  Training loss: 2.1489...  0.1283 sec/batch
# Epoch: 1/20...  Training Step: 440...  Training loss: 2.3318...  0.1183 sec/batch
# Epoch: 1/20...  Training Step: 441...  Training loss: 2.3083...  0.1364 sec/batch
# Epoch: 1/20...  Training Step: 442...  Training loss: 2.1488...  0.1213 sec/batch
# Epoch: 1/20...  Training Step: 443...  Training loss: 2.1715...  0.1058 sec/batch
# Epoch: 1/20...  Training Step: 444...  Training loss: 2.1627...  0.1334 sec/batch
# Epoch: 1/20...  Training Step: 445...  Training loss: 2.2064...  0.1108 sec/batch
# Epoch: 1/20...  Training Step: 446...  Training loss: 2.1740...  0.1273 sec/batch
# Epoch: 1/20...  Training Step: 447...  Training loss: 2.2715...  0.1354 sec/batch
# Epoch: 1/20...  Training Step: 448...  Training loss: 2.0999...  0.1349 sec/batch
# Epoch: 1/20...  Training Step: 449...  Training loss: 2.1259...  0.1258 sec/batch
# Epoch: 1/20...  Training Step: 450...  Training loss: 2.3389...  0.0968 sec/batch
# Epoch: 1/20...  Training Step: 451...  Training loss: 2.1832...  0.1479 sec/batch
# Epoch: 1/20...  Training Step: 452...  Training loss: 2.0661...  0.1243 sec/batch
# Epoch: 1/20...  Training Step: 453...  Training loss: 2.1427...  0.1283 sec/batch
# Epoch: 1/20...  Training Step: 454...  Training loss: 2.2028...  0.1073 sec/batch
# Epoch: 1/20...  Training Step: 455...  Training loss: 2.1968...  0.1188 sec/batch
# Epoch: 1/20...  Training Step: 456...  Training loss: 2.1485...  0.1098 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-119-ad76a1595262> in <module>()
#      28                                                  model.final_state,
#      29                                                  model.optimizer],
# ---> 30                                                  feed_dict=feed)
#      31
#      32             end = time.time()
#
# C:\ProgramData\Anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\ProgramData\Anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# C:\ProgramData\Anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\ProgramData\Anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# C:\ProgramData\Anaconda3\envs\dlnd-tf-lab\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = CharRNN(len(vocab), lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
tf.train.latest_checkpoint('checkpoints')

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(samp)

# %%
checkpoint = 'checkpoints/i200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)

# %%
checkpoint = 'checkpoints/i600_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)

# %%
checkpoint = 'checkpoints/i1200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
